# %% [markdown]
# # Hill Valley Project
# <hr>

# %% [markdown]
# ## Objective:- The goal of the Hill Valley Project is to develop a machine learning model that can accurately classify a set of given data points as either forming a hill or a valley when plotted on a graph using matplotlib. The project aims to leverage supervised learning techniques to train the model on labeled datasets, enabling it to generalize and make predictions on new, unseen data points.

# %% [markdown]
# ## Data Source:- https://github.com/YBI-Foundation/Dataset/blob/main/Hill%20Valley%20Dataset.csv

# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Hill%20Valley%20Dataset.csv')

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0     39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1      1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2  68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3  44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4      5.70      5.40      5.28      5.38      5.27      5.61      6.00
#
#          V8        V9       V10  ...       V92       V93       V94       V95  \
# 0     39.53     38.81     38.79  ...     36.62     36.92     38.80     38.52
# 1      1.70      1.75      1.78  ...      1.80      1.79      1.77      1.74
# 2  73268.61  74465.84  72503.37  ...  73438.88  71053.35  71112.62  74916.48
# 3  37668.32  40980.89  38466.15  ...  42625.67  40684.20  46960.73  44546.80
# 4      5.38      5.34      5.87  ...      5.17      5.67      5.60      5.94
#
#         V96       V97       V98       V99      V100  Class
# ...

# %%
df.shape
# Out:
# (1212, 101)

# %%
df.head().T
# Out:
#            0     1         2         3     4
# V1     39.02  1.83  68177.69  44889.06  5.70
# V2     36.49  1.71  66138.42  39191.86  5.40
# V3     38.20  1.77  72981.88  40728.46  5.28
# V4     38.85  1.77  74304.33  38576.36  5.38
# V5     39.38  1.68  67549.66  45876.06  5.27
# ...      ...   ...       ...       ...   ...
# V97    36.73  1.80  66348.97  47139.44  5.22
# V98    39.46  1.78  71063.72  43095.68  5.30
# V99    37.50  1.75  67404.27  40888.34  5.73
# V100   39.10  1.69  74920.24  39615.19  5.91
# Class   0.00  1.00      1.00      0.00  0.00
#
# [101 rows x 5 columns]

# %% [markdown]
# ## Describe Data

# %%
df.describe()
# Out:
#                   V1             V2             V3             V4  \
# count    1212.000000    1212.000000    1212.000000    1212.000000
# mean     8169.091881    8144.306262    8192.653738    8176.868738
# std     17974.950461   17881.049734   18087.938901   17991.903982
# min         0.920000       0.900000       0.850000       0.890000
# 25%        19.602500      19.595000      18.925000      19.277500
# 50%       301.425000     295.205000     297.260000     299.720000
# 75%      5358.795000    5417.847500    5393.367500    5388.482500
# max    117807.870000  108896.480000  119031.350000  110212.590000
#
#                   V5             V6             V7             V8  \
# count    1212.000000    1212.000000    1212.000000    1212.000000
# mean     8128.297211    8173.030008    8188.582748    8183.641543
# std     17846.757963   17927.114105   18029.562695   18048.582159
# min         0.880000       0.860000       0.870000       0.650000
# ...

# %%
df.isna().value_counts()
# Out:
# V1     V2     V3     V4     V5     V6     V7     V8     V9     V10    V11    V12    V13    V14    V15    V16    V17    V18    V19    V20    V21    V22    V23    V24    V25    V26    V27    V28    V29    V30    V31    V32    V33    V34    V35    V36    V37    V38    V39    V40    V41    V42    V43    V44    V45    V46    V47    V48    V49    V50    V51    V52    V53    V54    V55    V56    V57    V58    V59    V60    V61    V62    V63    V64    V65    V66    V67    V68    V69    V70    V71    V72    V73    V74    V75    V76    V77    V78    V79    V80    V81    V82    V83    V84    V85    V86    V87    V88    V89    V90    V91    V92    V93    V94    V95    V96    V97    V98    V99    V100   Class
# ...

# %%
df.isnull().value_counts()
# Out:
# V1     V2     V3     V4     V5     V6     V7     V8     V9     V10    V11    V12    V13    V14    V15    V16    V17    V18    V19    V20    V21    V22    V23    V24    V25    V26    V27    V28    V29    V30    V31    V32    V33    V34    V35    V36    V37    V38    V39    V40    V41    V42    V43    V44    V45    V46    V47    V48    V49    V50    V51    V52    V53    V54    V55    V56    V57    V58    V59    V60    V61    V62    V63    V64    V65    V66    V67    V68    V69    V70    V71    V72    V73    V74    V75    V76    V77    V78    V79    V80    V81    V82    V83    V84    V85    V86    V87    V88    V89    V90    V91    V92    V93    V94    V95    V96    V97    V98    V99    V100   Class
# ...

# %%
sum(df.isnull().sum()) #checking whether any column has null values
# Out:
# 0

# %% [markdown]
# Since, answer is zero, that means no null values in the database

# %% [markdown]
# ## Data Visualization

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0     39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1      1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2  68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3  44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4      5.70      5.40      5.28      5.38      5.27      5.61      6.00
#
#          V8        V9       V10  ...       V92       V93       V94       V95  \
# 0     39.53     38.81     38.79  ...     36.62     36.92     38.80     38.52
# 1      1.70      1.75      1.78  ...      1.80      1.79      1.77      1.74
# 2  73268.61  74465.84  72503.37  ...  73438.88  71053.35  71112.62  74916.48
# 3  37668.32  40980.89  38466.15  ...  42625.67  40684.20  46960.73  44546.80
# 4      5.38      5.34      5.87  ...      5.17      5.67      5.60      5.94
#
#         V96       V97       V98       V99      V100  Class
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(df.iloc[0]);
ax.plot(df.iloc[2]);

# %%
df[df['Class']==1].head()
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 1       1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2   68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 8      25.97     25.58     25.06     25.34     25.96     25.54     26.34
# 9    7354.68   7451.58   6605.84   7479.67   6974.47   7562.17   7836.13
# 10    193.98    165.62    195.56    163.74    164.69    191.74    180.09
#
#           V8        V9       V10  ...       V92       V93       V94       V95  \
# 1       1.70      1.75      1.78  ...      1.80      1.79      1.77      1.74
# 2   73268.61  74465.84  72503.37  ...  73438.88  71053.35  71112.62  74916.48
# 8      25.02     26.30     24.80  ...     24.83     24.97     25.32     25.23
# 9    7694.08   6538.31   6981.51  ...   7745.83   6825.93   6609.95   8057.45
# 10    197.11    203.64    181.33  ...    162.93    182.15    174.35    192.57
#
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.isna().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
#         ..
# V97      0
# V98      0
# V99      0
# V100     0
# Class    0
# Length: 101, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Columns: 101 entries, V1 to Class
# dtypes: float64(100), int64(1)
# memory usage: 956.5 KB

# %% [markdown]
# Our data is too much spread out, we have to normalize the data
#
# So, we will normalize our data after spliting the data into X and Y

# %% [markdown]
# ## Define target variable (y) and feature variables (x)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0     39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1      1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2  68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3  44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4      5.70      5.40      5.28      5.38      5.27      5.61      6.00
#
#          V8        V9       V10  ...       V92       V93       V94       V95  \
# 0     39.53     38.81     38.79  ...     36.62     36.92     38.80     38.52
# 1      1.70      1.75      1.78  ...      1.80      1.79      1.77      1.74
# 2  73268.61  74465.84  72503.37  ...  73438.88  71053.35  71112.62  74916.48
# 3  37668.32  40980.89  38466.15  ...  42625.67  40684.20  46960.73  44546.80
# 4      5.38      5.34      5.87  ...      5.17      5.67      5.60      5.94
#
#         V96       V97       V98       V99      V100  Class
# ...

# %%
X = df.drop("Class",axis=1)

# %%
y = df['Class']

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0     39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1      1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2  68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3  44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4      5.70      5.40      5.28      5.38      5.27      5.61      6.00
#
#          V8        V9       V10  ...       V91       V92       V93       V94  \
# 0     39.53     38.81     38.79  ...     37.57     36.62     36.92     38.80
# 1      1.70      1.75      1.78  ...      1.71      1.80      1.79      1.77
# 2  73268.61  74465.84  72503.37  ...  69384.71  73438.88  71053.35  71112.62
# 3  37668.32  40980.89  38466.15  ...  47653.60  42625.67  40684.20  46960.73
# 4      5.38      5.34      5.87  ...      5.52      5.17      5.67      5.60
#
#         V95       V96       V97       V98       V99      V100
# ...

# %%
y.value_counts()
# Out:
# 0    606
# 1    606
# Name: Class, dtype: int64

# %%
from sklearn.preprocessing import Normalizer
norm = Normalizer()

norm.fit(X)
X = pd.DataFrame(norm.transform(X))

# %%
cols = [f"V{i}" for i in range(1,101)]
X.columns = cols

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  0.104934  0.098130  0.102729  0.104477  0.105902  0.106870  0.099555
# 1  0.102912  0.096163  0.099537  0.099537  0.094476  0.100100  0.101225
# 2  0.093609  0.090809  0.100206  0.102021  0.092747  0.095243  0.094971
# 3  0.107010  0.093428  0.097091  0.091961  0.109363  0.112123  0.111116
# 4  0.105011  0.099484  0.097273  0.099115  0.097089  0.103353  0.110538
#
#          V8        V9       V10  ...       V91       V92       V93       V94  \
# 0  0.106305  0.104369  0.104315  ...  0.101034  0.098480  0.099286  0.104342
# 1  0.095601  0.098413  0.100100  ...  0.096163  0.101225  0.100662  0.099537
# 2  0.100599  0.102243  0.099549  ...  0.095267  0.100833  0.097558  0.097639
# 3  0.089796  0.097693  0.091698  ...  0.113600  0.101614  0.096986  0.111948
# 4  0.099115  0.098378  0.108143  ...  0.101695  0.095247  0.104458  0.103168
#
#         V95       V96       V97       V98       V99      V100
# ...

# %%
plt.plot(X.iloc[1]) # Hill

# %%
plt.plot(X.iloc[2]) # Hill

# %%
plt.plot(X.iloc[0]) # Valley

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(X,y,test_size=0.2,random_state=23)

# %%
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((969, 100), (243, 100), (969,), (243,))

# %% [markdown]
# ## Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=23)
clf.fit(train_x,train_y)
# Out:
# RandomForestClassifier(random_state=23)

# %%
clf.score(test_x,test_y)
# Out:
# 0.9876543209876543

# %% [markdown]
# ## Model Evaluation

# %%
y_preds = clf.predict(test_x)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(test_y,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       122
#            1       0.98      0.99      0.99       121
#
#     accuracy                           0.99       243
#    macro avg       0.99      0.99      0.99       243
# weighted avg       0.99      0.99      0.99       243

# %%
confusion_matrix(test_y,y_preds)
# Out:
# array([[120,   2],
#        [  1, 120]], dtype=int64)

# %% [markdown]
# ## Predictions

# %%
rd_sample = train_x.sample(1)
rd_sample
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 77  0.097498  0.101585  0.101383  0.109389  0.105874  0.099617  0.094975
#
#           V8        V9       V10  ...       V91      V92       V93       V94  \
# 77  0.101366  0.094992  0.107421  ...  0.102947  0.10917  0.102796  0.097179
#
#          V95       V96       V97       V98       V99      V100
# 77  0.101266  0.108699  0.100896  0.109406  0.100273  0.098692
#
# [1 rows x 100 columns]

# %%
rd_sample_pred = clf.predict(rd_sample)
rd_sample_pred
# Out:
# array([0], dtype=int64)

# %% [markdown]
# Here, it predicts a zero (0), so, let's check the result by plotting the points

# %%
plt.plot(rd_sample.T)

# %% [markdown]
# So, our model was able to correctly predict, that these data points form a valley

# %% [markdown]
# ## Explanation

# %% [markdown]
# The Random Forest Classifier was employed to predict whether a set of data points forms a hill or a valley in the Hill Valley Project. The model demonstrated high performance, as evident from the classification report:
#
# * **Accuracy**:
# The model achieved an impressive accuracy of 99%, indicating its ability to correctly classify the majority of data points.
#
# * **Precision and Recall**:
# Both classes (0 for valley and 1 for hill) exhibit high precision (99% for class 0 and 98% for class 1) and recall (98% for class 0 and 99% for class 1). These metrics highlight the model's capability to accurately identify instances of both hills and valleys while minimizing false positives and false negatives.
#
# * **F1-Score**:
# The F1-score, which balances precision and recall, is exceptionally high for both classes (99% for class 0 and 99% for class 1). This underscores the robustness of the model in providing accurate predictions.
#
# * **Observations**:
# No significant challenges or anomalies were observed during the model evaluation. The model performs consistently across both classes, indicating a strong generalization to new data.
